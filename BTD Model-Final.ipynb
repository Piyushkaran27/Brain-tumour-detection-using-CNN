# %% [markdown]
# # BRAIN TUMOR PREDICTION USING CNN
#
# ## THIS FILE HAS MODEL BUILDING

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen =  ImageDataGenerator(rescale = 1./255,shear_range = 0.2,zoom_range = 0.2,horizontal_flip = True)
test_datagen =  ImageDataGenerator(rescale = 1./255)

# %%
x_train = train_datagen.flow_from_directory("BTD/train",target_size = (64,64),batch_size = 32, class_mode ="categorical")
x_test = test_datagen.flow_from_directory("BTD/test",target_size = (64,64),batch_size = 32, class_mode ="categorical")
# x_train = train_datagen.flow_from_directory("BTD/train",target_size = (64,64),batch_size = 8, class_mode ="categorical")
# x_test = test_datagen.flow_from_directory("BTD/test",target_size = (64,64),batch_size = 8, class_mode ="categorical")
# Out:
# Found 212 images belonging to 2 classes.
# Found 41 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Convolution2D(32,(3,3), input_shape=(64,64,3)))
model.add(MaxPooling2D(2,2))
model.add(Flatten())

# %%
model.add(Dense(units = 256,activation = "relu",kernel_initializer = "random_uniform"))
model.add(Dense(units = 256,activation = "relu",kernel_initializer = "random_uniform"))
model.add(Dense(units = 2,activation = "softmax",kernel_initializer = "random_uniform"))
model.compile("sgd",loss = "categorical_crossentropy",metrics = ["accuracy"])

# %%
model.fit_generator(x_train ,steps_per_epoch = 7 ,epochs = 1000,validation_data= x_test , validation_steps = 1)
# model.fit_generator(x_train ,steps_per_epoch = 24 ,epochs = 100,validation_data= x_test , validation_steps = 8)
# Out:
# C:\Users\piyus\AppData\Local\Temp\ipykernel_22536\3915276708.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(x_train ,steps_per_epoch = 7 ,epochs = 1000,validation_data= x_test , validation_steps = 1)
# Epoch 1/1000
# 7/7 [==============================] - 4s 538ms/step - loss: 0.6576 - accuracy: 0.6321 - val_loss: 0.6552 - val_accuracy: 0.5312
# Epoch 2/1000
# 7/7 [==============================] - 1s 131ms/step - loss: 0.6397 - accuracy: 0.6321 - val_loss: 0.6399 - val_accuracy: 0.5625
# Epoch 3/1000
# 7/7 [==============================] - 1s 150ms/step - loss: 0.6343 - accuracy: 0.6321 - val_loss: 0.7098 - val_accuracy: 0.4375
# Epoch 4/1000
# 7/7 [==============================] - 1s 126ms/step - loss: 0.6259 - accuracy: 0.6321 - val_loss: 0.6958 - val_accuracy: 0.4375
# Epoch 5/1000
# ...

# %%
model.save("BTD2.h5")
